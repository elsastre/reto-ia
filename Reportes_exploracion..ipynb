# %% [markdown]
# # Reportes de exploración — Reto 1 Ceibal
#
# Corre `generar_reportes` (calidad + comparación estructural) sobre las 4 bases de CREA.
#
# **Comparaciones válidas** (las tablas NO son relacionables entre sí):
# - Docentes 2025 vs Docentes 2026
# - Estudiantes 2025 vs Estudiantes 2026
#
# NO se compara docentes vs estudiantes (columnas distintas) ni se hace JOIN por ID.

# %%
import pandas as pd
from generar_reportes import generar_reportes

BASE = "/Users/gustavohunter/Downloads/Datos Ceibal Reto 1 2026"

archivos = {
    "doc2025":  f"{BASE}/datosUCU2025_doc.xlsx",
    "doc2026":  f"{BASE}/datosUCU2026_doc.xlsx",
    "estu2025": f"{BASE}/datosUCU2025_estu.xlsx",
    "estu2026": f"{BASE}/datosUCU2026_estu.xlsx",
}

dfs = {nombre: pd.read_excel(ruta) for nombre, ruta in archivos.items()}

for nombre, df in dfs.items():
    print(f"{nombre:9s} -> filas: {len(df):>7} | columnas: {len(df.columns)}")
# Out:
# doc2025   -> filas:  148372 | columnas: 16
# doc2026   -> filas:  155745 | columnas: 16
# estu2025  -> filas:  547142 | columnas: 15
# estu2026  -> filas:  504702 | columnas: 15

# %% [markdown]
# ## 1) Docentes: 2025 vs 2026

# %%
print(generar_reportes(dfs["doc2025"], dfs["doc2026"],
                       name1="doc2025", name2="doc2026"))
# Out:
# ########## REPORTES DE CALIDAD DE DATOS: doc2025 vs doc2026 ##########
#
# >>> DUPLICADOS EN 'doc2025'
# DUPLICADOS
# ========================================
# Filas totales: 148372
# Columnas consideradas: todas
# Grupos de valores repetidos: 6205
# Filas involucradas en duplicados (incluye la primera copia): 12654
# Filas 'extra' (sobrarían si se deduplica dejando 1 copia por grupo): 6449
# Porcentaje de filas extra sobre el total: 4.3%
#
# >>> DUPLICADOS EN 'doc2026'
# DUPLICADOS
# ========================================
# Filas totales: 155745
# Columnas consideradas: todas
# Grupos de valores repetidos: 553
# Filas involucradas en duplicados (incluye la primera copia): 1194
# Filas 'extra' (sobrarían si se deduplica dejando 1 copia por grupo): 641
# Porcentaje de filas extra sobre el total: 0.4%
#
# >>> COMPARACIÓN ENTRE DATASETS
# COMPARACIÓN: doc2025  vs  doc2026
# ============================================================
# Filas totales -> doc2025: 148372 | doc2026: 155745
# Columnas categóricas comparadas: ['ID_persona', 'ID_CENTRO', 'Sexo', 'tipo_centro', 'Rubro', 'dept_nombre', 'ciclo', 'grado', 'grupo']
# Columnas numéricas comparadas:   ['Dias6', 'Dias5', 'Dias4']
#
# 1) COLUMNAS QUE NO COINCIDEN
# ------------------------------------------------------------
# Solo en doc2025:
#   - Zona
#   - Materia
#   - Contexto Sociocultural
#   - IvsMedia
# Solo en doc2026:
#   - ZONA
#   - MATERIA
#   - CONTEXTO
#   - IVSMEDIA
#
# 2) CATEGORÍAS QUE NO COINCIDEN
# ------------------------------------------------------------
# Columna 'ID_persona':
#   Solo en doc2025:
#     (ninguna)
#   Solo en doc2026:
#     - id_36779
#     - id_36780
#     - id_36781
#     - id_36782
#     - id_36783
#     - id_36784
#     - id_36785
#     - id_36786
#     - id_36787
#     - id_36788
#     - id_36789
#     - id_36790
#     - id_36791
#     - id_36792
#     - id_36793
#     - id_36794
#     - id_36795
#     - id_36796
#     - id_36797
#     - id_36798
#     ... y 1559 más
# Columna 'ID_CENTRO':
#   Solo en doc2025:
#     (ninguna)
#   Solo en doc2026:
#     - centro_2509
#     - centro_2510
#     - centro_2511
#     - centro_2512
#     - centro_2513
#     - centro_2514
#     - centro_2515
#     - centro_2516
#     - centro_2517
#     - centro_2518
#     - centro_2519
#     - centro_2520
#     - centro_2521
#     - centro_2522
#     - centro_2523
#     - centro_2524
#     - centro_2525
#     - centro_2526
#     - centro_2527
#     - centro_2528
#     ... y 61 más
# Columna 'ciclo':
#   Solo en doc2025:
#     - articulacion educacion media basica
#     - bachillerato profesional
#   Solo en doc2026:
#     - ctt especializacion
#     - educacion media basica tecnologica
# Columna 'grado':
#   Solo en doc2025:
#     (ninguna)
#   Solo en doc2026:
#     - no aplica
# Columna 'grupo':
#   Solo en doc2025:
#     - 1o.ems g.18
#     - 1o.ems g.19
#     - 2do.csh g. 5 nc-ha
#     - 2do.csh g.14
#     - 2do.csh g.15
#     - 2do.csh g.16
#     - 2do.ct g. 5
#     - 2do.ct g. 6
#     - 2do.ct g. 7
#     - 2do.ct g. 8
#     - 2do.ct g. 9
#     - 2do.ct g.10
#     - 2do.ct g.11
#     - 2do.ct g.12
#     - 2do.ct g.13
#     - 2do.ct g.14
#     - 2do.ct g.15
#     - 3ro.cshd g. 1
#     - 3ro.cshd g. 2
#     - 3ro.cshd g. 3
#     ... y 89 más
#   Solo en doc2026:
#     - 1b||0
#     - 1c||0
#     - 1d||0
#     - 1e||0
#     - 1f||0
#     - 1ro. g. 1_anual_s1
#     - 2do.csh g. 6 nc-ha
#     - 2do.cv g. 1
#     - 2do.cv g. 2
#     - 2do.cv g. 3
#     - 2do.cv g. 4
#     - 2do.cv g. 5
#     - 2do.cv g. 6
#     - 2do.cv g. 7
#     - 2do.cv g. 8
#     - 3ro.c.art. g. 4
#     - 3ro.cad g. 1
#     - 3ro.ct g. 1
#     - 3ro.ct g. 2
#     - 3ro.ct g. 3
#     ... y 82 más
#
# RESUMEN
# ------------------------------------------------------------
#   Combinaciones comunes comparadas: 1
#   Combinaciones con cantidad desfasada: 3
#   Columnas con categorías desfasadas: ['ID_persona', 'ID_CENTRO', 'ciclo', 'grado', 'grupo']

# %% [markdown]
# ## 2) Estudiantes: 2025 vs 2026

# %%
print(generar_reportes(dfs["estu2025"], dfs["estu2026"],
                       name1="estu2025", name2="estu2026"))
# Out:
# ######### REPORTES DE CALIDAD DE DATOS: estu2025 vs estu2026 #########
#
# >>> DUPLICADOS EN 'estu2025'
# DUPLICADOS
# ========================================
# Filas totales: 547142
# Columnas consideradas: todas
# Grupos de valores repetidos: 0
# Filas involucradas en duplicados (incluye la primera copia): 0
# Filas 'extra' (sobrarían si se deduplica dejando 1 copia por grupo): 0
# Porcentaje de filas extra sobre el total: 0.0%
#
# >>> DUPLICADOS EN 'estu2026'
# DUPLICADOS
# ========================================
# Filas totales: 504702
# Columnas consideradas: todas
# Grupos de valores repetidos: 0
# Filas involucradas en duplicados (incluye la primera copia): 0
# Filas 'extra' (sobrarían si se deduplica dejando 1 copia por grupo): 0
# Porcentaje de filas extra sobre el total: 0.0%
#
# >>> COMPARACIÓN ENTRE DATASETS
# COMPARACIÓN: estu2025  vs  estu2026
# ============================================================
# Filas totales -> estu2025: 547142 | estu2026: 504702
# Columnas categóricas comparadas: ['ID_persona', 'ID_CENTRO', 'Sexo', 'tipo_centro', 'Rubro', 'dept_nombre', 'ciclo', 'grado', 'grupo']
# Columnas numéricas comparadas:   ['Dias6', 'Dias5', 'Dias4']
#
# 1) COLUMNAS QUE NO COINCIDEN
# ------------------------------------------------------------
# Solo en estu2025:
#   - Zona
#   - Contexto Sociocultural
#   - IvsMedia
# Solo en estu2026:
#   - ZONA
#   - CONTEXTO
#   - IVSMEDIA
#
# 2) CATEGORÍAS QUE NO COINCIDEN
# ------------------------------------------------------------
# Columna 'ID_persona':
#   Solo en estu2025:
#     - id_504703
#     - id_504704
#     - id_504705
#     - id_504706
#     - id_504707
#     - id_504708
#     - id_504709
#     - id_504710
#     - id_504711
#     - id_504712
#     - id_504713
#     - id_504714
#     - id_504715
#     - id_504716
#     - id_504717
#     - id_504718
#     - id_504719
#     - id_504720
#     - id_504721
#     - id_504722
#     ... y 42420 más
#   Solo en estu2026:
#     (ninguna)
# Columna 'ID_CENTRO':
#   Solo en estu2025:
#     (ninguna)
#   Solo en estu2026:
#     - centro_2598
#     - centro_2599
# Columna 'Sexo':
#   Solo en estu2025:
#     (ninguna)
#   Solo en estu2026:
#     - 0
# Columna 'ciclo':
#   Solo en estu2025:
#     - bachillerato profesional
#     - bachillerato profesional trayectos
#     - ciclo basico tecnologico
#   Solo en estu2026:
#     - ctt especializacion
#     - educacion media basica tecnologica
# Columna 'grado':
#   Solo en estu2025:
#     - no aplica
#     - seminario praxis
#   Solo en estu2026:
#     (ninguna)
# Columna 'grupo':
#   Solo en estu2025:
#     - 1o.ems g.18
#     - 1o.ems g.19
#     - 2do. g. 1_2osem
#     - 2do.csh g.14
#     - 2do.csh g.15
#     - 2do.csh g.16
#     - 2do.ct g. 5
#     - 2do.ct g. 6
#     - 2do.ct g. 7
#     - 2do.ct g. 8
#     - 2do.ct g. 9
#     - 2do.ct g.10
#     - 2do.ct g.11
#     - 2do.ct g.12
#     - 2do.ct g.13
#     - 2do.ct g.14
#     - 2do.ct g.15
#     - 3ro. g. 1_2osem
#     - 3ro.cshd g. 1
#     - 3ro.cshd g. 2
#     ... y 81 más
#   Solo en estu2026:
#     - 1b||0
#     - 1c||0
#     - 1d||0
#     - 1e||0
#     - 1f||0
#     - 1ro. g. 1_anual_s1
#     - 2do.biol. g. 1_2osem
#     - 2do.csh g. 6 nc-ha
#     - 2do.cv g. 1
#     - 2do.cv g. 2
#     - 2do.cv g. 3
#     - 2do.cv g. 4
#     - 2do.cv g. 5
#     - 2do.cv g. 6
#     - 2do.cv g. 7
#     - 2do.cv g. 8
#     - 2do.hum. g. 1_2osem
#     - 3ro.c.art. g. 4
#     - 3ro.cad g. 1
#     - 3ro.ct g. 1
#     ... y 70 más
#
# RESUMEN
# ------------------------------------------------------------
#   Combinaciones comunes comparadas: 1
#   Combinaciones con cantidad desfasada: 2
#   Columnas con categorías desfasadas: ['ID_persona', 'ID_CENTRO', 'Sexo', 'ciclo', 'grado', 'grupo']
